# %%
print("OK")
# Out:
# OK

# %%
print("Now its working!!")
# Out:
# Now its working!!

# %%
# %pip install -qU langchain-community pypdf
# Out:
# Note: you may need to restart the kernel to use updated packages.
# [notice] A new release of pip is available: 23.0.1 -> 26.0.1
# [notice] To update, run: python.exe -m pip install --upgrade pip

# %%
from langchain_community.document_loaders import PyPDFLoader

file_path = r"D:\LLMOPSKrishnaik\ecomm-prod-assistant\notebook\pdf_data\Mr_DIVYANG_THAKKAR _CHOLA MS.pdf"

# %%
loader = PyPDFLoader(file_path)

# %%
docs = loader.load()

# %%
docs
# Out:
# [Document(metadata={'producer': 'Skia/PDF m145', 'creator': 'Mozilla/5.0 (Windows NT 10.0; Win64; x64) AppleWebKit/537.36 (KHTML, like Gecko) Chrome/145.0.0.0 Safari/537.36', 'creationdate': '2026-02-24T08:01:14+00:00', 'title': 'about:blank', 'moddate': '2026-02-24T08:01:14+00:00', 'source': 'D:\\LLMOPSKrishnaik\\ecomm-prod-assistant\\notebook\\pdf_data\\Mr_DIVYANG_THAKKAR _CHOLA MS.pdf', 'total_pages': 3, 'page': 0, 'page_label': '1'}, page_content='CHOLAMANDALAM MS GENERAL INSURANCE CO. LTD.\nOPTIONZ, 2nd Floor, OPP Regenta Hotel, 18, S. P. Colony, Off C G Road,\nAhmedabad AHMEDABAD GUJARAT State Code(24)\nGSTIN: 24AABCC6633K7ZJ\nIRDA Registration Number : 123\nProposal Details\nProposal No.\nPRDKIA17410579\nPolicy\nEffective Date\nOD\n06-Mar-2026\nPolicy Expiry\nDate OD\n05-Mar-2027\nPolicy Tenure TP\n1 Year\nPolicy\nEffective Date\nTP\n06-Mar-2026\nPolicy Expiry\nDate TP\n05-Mar-2027\nCPA Details\nPolicy\nEffective Date\nCPA\n06-Mar-2026\nPolicy Expiry\nDate CPA\n05-Mar-2027\nPr
# ...

# %%
from langchain_community.document_loaders.csv_loader import CSVLoader

# %%
csv_path = file_path=r'D:\\LLMOPSKrishnaik\\ecomm-prod-assistant\\data\\product_reviews.csv'

# %%
loader = CSVLoader(
    file_path=csv_path,
    csv_args={
        "delimiter": ",",
        "fieldnames": ["product_id", "product_title", "rating", "total_reviews", "price", "top_reviews"],
    },
)

# %%
docs = loader.load()

# %%
docs
# Out:
# [Document(metadata={'source': 'D:\\\\LLMOPSKrishnaik\\\\ecomm-prod-assistant\\\\data\\\\product_reviews.csv', 'row': 0}, page_content='product_id: product_id\nproduct_title: product_title\nrating: rating\ntotal_reviews: total_reviews\nprice: price\ntop_reviews: top_reviews'),
#  Document(metadata={'source': 'D:\\\\LLMOPSKrishnaik\\\\ecomm-prod-assistant\\\\data\\\\product_reviews.csv', 'row': 1}, page_content='product_id: itmc2e910b4d0b1c\nproduct_title: Apple iPhone 16 (Pink, 128 GB)\nrating: 4.6\ntotal_reviews: 6,023\nprice: â‚¹69,900\ntop_reviews: 4 | Very Good | Nice camera quality Like DSLR | Adarsh Gupta | Certified Buyer, Varanasi | 1 month ago | 27 | 2 | https://www.flipkart.com/reviews/MOBHCUW8YPERJQJP:120?reviewId=e7002298-911e-4550-b6e4-93dc90b9b56b || 5 | Super! | Satisfied | Amit Kumar Chaudhary | Certified Buyer, Patna | 7 months ago | 1594 | 467 | https://www.flipkart.com/reviews/MOBH4DQFG8NKFRDY:191?reviewId=385178ef-7ade-455b-a949-0d44ff0a6890'),
# ...
